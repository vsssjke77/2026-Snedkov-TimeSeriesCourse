# %% [markdown]
# # Анализ и прогнозирование временных рядов методами искусственного интеллекта
#
# ## **Практическая работа 2. Поиск по образцу.**

# %% [markdown]
# Смените рабочую директорию с помощью команды `chdir()`. Для этого передайте этой команде свой путь до каталога, в котором содержатся материалы второй практической работы. После выполнения этой команды все последующие операции с файлами и каталогами будут производиться относительно указанного каталога.

# %%
import os

practice_dir_path = 'C:/Users/wala-/Desktop/tscourse/2026-Snedkov-TimeSeriesCourse/practice/02 Similarity search'
os.chdir(practice_dir_path)

# %% [markdown]
# Выполните команды, которые автоматически перезагружают все импортированные модули при их изменении.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Импортируйте библиотеки и модули, необходимые для реализации практической работы 2.

# %%
# %pip install mass-ts
# %pip install sktime
# Out:
# Requirement already satisfied: mass-ts in C:\Python311\Lib\site-packages (0.1.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in C:\Python311\Lib\site-packages (from mass-ts) (1.26.4)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# Requirement already satisfied: sktime in C:\Python311\Lib\site-packages (0.24.0)
# Requirement already satisfied: numpy<1.27,>=1.21.0 in C:\Python311\Lib\site-packages (from sktime) (1.26.4)
# Requirement already satisfied: pandas<2.2.0,>=1.1.0 in C:\Python311\Lib\site-packages (from sktime) (2.1.4)
# Requirement already satisfied: packaging in C:\Python311\Lib\site-packages (from sktime) (23.2)
# Requirement already satisfied: scikit-base<0.7.0 in C:\Python311\Lib\site-packages (from sktime) (0.6.2)
# Requirement already satisfied: scikit-learn<1.4.0,>=0.24.0 in C:\Python311\Lib\site-packages (from sktime) (1.3.2)
# Requirement already satisfied: scipy<2.0.0,>=1.2.0 in C:\Python311\Lib\site-packages (from sktime) (1.17.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Python311\Lib\site-packages (from pandas<2.2.0,>=1.1.0->sktime) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in C:\Python311\Lib\site-packages (from pandas<2.2.0,>=1.1.0->sktime) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in C:\Python311\Lib\site-packages (from pandas<2.2.0,>=1.1.0->sktime) (2025.2)
# Requirement already satisfied: joblib>=1.1.1 in C:\Python311\Lib\site-packages (from scikit-learn<1.4.0,>=0.24.0->sktime) (1.6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in C:\Python311\Lib\site-packages (from scikit-learn<1.4.0,>=0.24.0->sktime) (3.7.0)
# Requirement already satisfied: cloudpickle>=3.0 in C:\Python311\Lib\site-packages (from joblib>=1.1.1->scikit-learn<1.4.0,>=0.24.0->sktime) (3.1.2)
# Requirement already satisfied: six>=1.5 in C:\Python311\Lib\site-packages (from python-dateutil>=2.8.2->pandas<2.2.0,>=1.1.0->sktime) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)

# %%
import numpy as np
import pandas as pd
import math
import timeit
import random
import mass_ts as mts
from IPython.display import display

from modules.distance_profile import brute_force
from modules.prediction import *
from modules.bestmatch import *
from modules.utils import *
from modules.plots import *
from modules.experiments import *
# Out:
# C:\Python311\Lib\site-packages\mass_ts\_mass_ts.py:17: UserWarning: GPU support will not work. You must pip install mass-ts[gpu].
#   warnings.warn(
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-4.1.1.min"</script>

# %% [markdown]
# ## **Часть 1.** Поиск по образцу на основе вычисленного профиля расстояния.
#
# **Задача поиска по образцу (subsequence matching)** заключается в нахождении $topK$ наиболее похожих подпоследовательностей временного ряда $T$ длины $n$ на заданный пользователем существенно более короткий временной ряд $Q$ длины $m$, называемый запросом, в смысле некоторой функции расстояния, $m \ll n$. При этом среди найденных подпоследовательностей не должно быть тривиальных совпадений.
#
# Две подпоследовательности $T_{i,m}$ и $T_{j,m}$ временного ряда $T$ являются **тривиальными совпадениями (trivial matches)**, если они пересекаются:
# \begin{equation}
# |i-j| \leqslant m.
# \end{equation}
#
# В общем случае условие пересечения записывается как $|i-j| \leqslant \xi m$, где задаваемый экспертом вещественный параметр $\xi$ $(0 < \xi \leqslant 1)$ имеет типичные значения 0.25, 0.5 или 1.
#
# Одним из вариантов решения данной задачи является вычисление профиля расстояния. Под **профилем расстояния** $DistProfile\in \mathbb{R}^{n-m+1}$ понимается вектор, содержащий расстояния между подпоследовательностями временного ряда $T \in \mathbb{R}^n$ и запросом $Q \in \mathbb{R}^m$, вычисленные с помощью некоторой неотрицательной симметричной функции расстояния $dist(\cdot,\cdot)$:
# \begin{equation}
# DistProfile(i) = dist(Q, T_{i,m}), \quad 1 \leqslant i \leqslant n-m+1.
# \end{equation}
#
# На основе вычисленного профиля расстояния в качестве $topK$ похожих подпоследовательностей ряда берутся те, которые имеют наименьшие расстояния до запроса:
# \begin{equation}
# C_{match} = \{T_{i,m}^k\}_{k=1}^{topK},\; где \; T_{i,m}^k \in T, \; i = argsort(DistProfile)(k), \; 1 \leqslant i \leqslant n-m+1.
# \end{equation}
#
# В части 1 практической работы 2 вы рассмотрите несколько алгоритмов вычисления профиля расстояния на примере алгоритмов грубой силы и MASS, а также примените результаты их выполнения для решения задачи поиска по образцу. В таблице ниже представлено их тезисное описание.
#
# | <h5> **Алгоритм** </h5> | <h5> **Описание** </h5> | <h5> **Вычислительная <br> сложность** </h5> |
# |--------------|------------------------------------------------------------------|:-----------------------------:|
# | <p>Brute Force</p>  | <ul><li>Наивный алгоритм</li><li>Z-нормализация запроса и подпоследовательностей ряда по стандартным формулам</li><li>Полное вычисление расстояний между запросом и подпоследовательностями ряда</li></ul> |            <p>$O(mn)$</p>            |
# | <p>MASS 1</p>       | <ul><li>Z-нормализация &#171;на лету&#187;</li><li>Применение свертки для вычисления скалярных произведений <br> между запросом и подпоследовательностями ряда</li><li>Выполнение свертки с помощью быстрого преобразования Фурье</li><li>Дополнение справа нулями запроса и временного ряда до удвоенной длины ряда</li><li>Реверс запроса</li></ul> |          <p>$O(n\log{n})$</p>          |
# | <p>MASS 2</p>       | <ul><li>MASS 1 – это алгоритм, на котором основан MASS 2</li><li>Вычисление половины свертки</li><li>Дополнение нулями справа только запроса до длины временного ряда</li></ul> |          <p>$O(n\log{n})$</p>          |
# | <font size="3">MASS 3</font>       | <ul><li>MASS 2 – это алгоритм, на котором основан MASS 3</li><li>Посегментная обработка временного ряда</li><li>Длина каждого сегмента (кроме, возможно, последнего) – степень двойки</li><li>Сегменты перекрываются на $m-1$ элементов</li></ul> |             <p>$O(\frac{n-k}{k-m}k\log{k})$, <br> где $k$ – длина сегмента </p>           |

# %% [markdown]
# ### **Задача 1.**
#
# В данном задании вам предстоит определить, имеет ли пациент заболевание сердца по снятой записи ЭКГ или нет. Решать данную задачу будем с помощью алгоритмов поиска по образцу.
#
# Сначала выполните считывание временного ряда и образца поиска из файлов *ECG.csv* и *ECG_query.csv* соответственно из директории *./datasets/part1*. Временной ряд представляет собой показания ЭКГ пациента, образец поиска – фрагмент ЭКГ, обозначающий некоторое кардиологическое заболевание.

# %%
ts_url = './datasets/part1/ECG.csv'
query_url = './datasets/part1/ECG_query.csv'

ts = read_ts(ts_url).reshape(-1)
query = read_ts(query_url).reshape(-1)

# %% [markdown]
# Далее выполните визулизацию временного ряда и образца поиска с помощью функции `plot_bestmatch_data()` из модуля *plots.py*.

# %%
plot_bestmatch_data(ts, query)
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id
# Реализуйте алгоритм грубой силы (brute force), заполнив одноименную функцию в модуле *distance_profile.py* недостающим кодом. Для этого воспользуйтесь псевдокодом алгоритма, который представлен ниже. После того как вычислен профиль расстояния, найдите $topK$ похожих подпоследовательностей на запрос с помощью функции `topK_match()` из *bestmatch.py*. Для исключения попадания тривиальных совпадений зададим $\xi = 0.5$ Далее параметр $\xi$ будем обозначать в коде как $excl\_zone\_frac$, а величину пересечения как $excl\_zone$, $excl\_zone = \lceil excl\_zone\_frac \cdot m \rceil$,
#
# <center><img src="https://github.com/mzym/TimeSeriesCourse/blob/main/practice/02%20Similarity%20search/img/brute_force.png?raw=true" width="400"></center>

# %%
topK = 2
excl_zone_frac = 0.5
excl_zone = math.ceil(len(query) * excl_zone_frac)
is_normalize = True

dist_profile = brute_force(ts, query, is_normalize)

naive_bestmatch_results = topK_match(dist_profile, excl_zone, topK)

# Выводим результаты
print(f"Индексы подпоследовательностей: {naive_bestmatch_results['indices']}")
print(f"Расстояния до запроса: {naive_bestmatch_results['distances']}")
# Out:
# Индексы подпоследовательностей: [1215, 193]
# Расстояния до запроса: [5.01641797172885, 18.030850173768776]

# %% [markdown]
# Напишите функцию `plot_bestmatch_results()` в модуле *plots.py* для визуализации найденных $topK$ похожих подпоследовательностей временного ряда на образец поиска. За основу возьмите функцию `plot_bestmatch_data()` и добавьте отображение найденных подпоследовательностей, выделив их тем же цветом, что и образец поиска.

# %%
plot_bestmatch_results(ts, query, naive_bestmatch_results)
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id="73373532-7197-4023-87f9-f15f8fb71024" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("73373532-7197-4023-87f9-f15f8fb71024")) {                    Plotly.newPlot(                        "73373532-7197-4023-87f9-f15f8fb71024",                        [{"line":{"color":"#EF553B"},"x":{"dtype":"i4","bdata":"...\\u002fAAAAP0AAAD+AAAA\...\u002fAQAAgAEAAIEBAACCAQAAgwEAAIQBAACFAQAAhgEAAIcBAACIAQAAiQEAAIoBAACLAQAAjAEAAI0BAACOAQAAjwEAAJABAACRAQAAkgEAAJMBAACUAQAAlQEAAJYBAACXAQAAmAEAAJkBAACaAQAAmwEAAJwBAACdAQAAngEAAJ8BAACgAQAAoQEAAKIBAACjAQAApAEAAA=="},"y":{"dtype":"f8","bdata":"5x2n6Egu9j9SSZ2AJsL7P8uhRbbzfQFA0ZFc\u002fkP6BUAy5q4l5AMOQIEmwoanFxRARIts5\u002fvpGUBv8IXJVAEgQCS5\u002fIf0+yJAnzws1JqmJUB4eqUsQ7wnQLdif9k9+ShAseHplbIsKUBhMlUwKkkoQKjGSzeJYSZA6+I2GsCbI0CNl24SgyAgQBsv3SQGQRhAF0hQ\u002fBhzD0DxY8xdS8j8P1wgQfFjzM2\u002fm1Wfq63YAMAW+8vuyUMOwAMJih9j7hTA4JwRpb3BGcARNjy9UpYdwK7YX3ZPPiDAhXzQs1lVIcD6fmq8dDMiwJayDHGs6yLA8fRKWYZ4I8C\u002fDpwzotQjwG3n+6nxEiTAPnlYqDVNJMAOvjCZKngkwDEIrBxahCTAjgbwFkhwJMAH8BZIUBwkwKCJsOHp1SPAyeU\u002fpN++IsCSy39Iv30fwO2ePCzUGgHAescpOpJLJUC+wRcmU1U+QJhMFYxKkkpAM8SxLm4bUkB3LSEf9PxUQM07TtGRpFVAEqW9wRcGVEAAAAAAAEB
AKe0NvjC5JUCEns2qz1UpQJZDi2zn2ytA5\u002fup8dKtLUAy5q4l5CMvQL1SliGORTBAGQRWDi0SMUCLbOf7qREyQLprCfmgVzNAGXPXEvLxNECZu5aQD+o2QEvIBz2bRTlAl\u002f+Qfvv6O0DM7snDQv0+QFg5tMh2HkFATfOOU3TUQkAOLbKd77dEQBE2PL1SxkZA+THmriX8SECzDHGsi1tLQOXyH9Jv501AswxxrIszUEDu68A5I3JRQNEi2\u002fl+plJAPzVeuknYU0ADCYofY45VQJyiI7n8U1dAqaROQBMlWUBlGeJYFxdbQHQkl\u002f+QHl1ArIvbaAAvX0Dc14FzRpxgQHEbDeAtVmFAMZkqGJX6YUDy0k1iEIRiQF5LyAc972JAyJi7lpA5Y0AUP8bctWJjQDj4wmSqamNAcF8HzhlRY0DY8PRKWRZjQOzAOSNKvWJAWmQ7309JYkCHFtnO971hQHctIR\u002f0HGFAvw6cM6 ...

# %% [markdown]
# ![equation.png](data:image/png;base64,...)
# Определите по полученным результатам, имеет ли человек сердечное заболевание или нет.

# %% [markdown]
# Так как алгоритм нашел подследовательности, которые соответствуют запросу, обозначающему сердечное заболевание, то можно сделать вывод что человек имеет сердечное заболевание

# %% [markdown]
# ### **Задача 2.**
#
# Проделайте такие же шаги для поиска по образцу, как и в задаче 1, но теперь вычислите профиль расстояния с помощью одной из выбранных вами версий алгоритма MASS. Для этого используйте стороннюю библиотеку *mass-ts*. Со списком всех функций, которые предоставляет данная библиотека, и их описанием вы можете ознакомиться в [репозитории библиотеки GitHub](https://github.com/matrix-profile-foundation/mass-ts).
#
# Обратите внимание, что MASS 2 и MASS 3 возвращают профиль расстояния в виде вектора комплексных чисел. Для дальнейшей работы с профилем расстояния используйте только вещественные части комплексных чисел.

# %%
topK = 2
excl_zone_frac = 0.5
excl_zone = math.ceil(len(query) * excl_zone_frac)
is_normalize = True

mass_bestmatch_results = {}

mass1_dist_profile = np.real(mts.mass(ts, query))
mass_bestmatch_results['MASS1'] = topK_match(mass1_dist_profile, excl_zone, topK)

mass1_dist_profile = np.real(mts.mass2(ts, query))
mass_bestmatch_results['MASS2'] = topK_match(mass1_dist_profile, excl_zone, topK)

mass1_dist_profile = np.real(mts.mass3(ts, query, 1024))
mass_bestmatch_results['MASS3'] = topK_match(mass1_dist_profile, excl_zone, topK)

print("Brute force:", naive_bestmatch_results['indices'], naive_bestmatch_results['distances'])

for algorithm, result in mass_bestmatch_results.items():
    print(f"\n{algorithm}:")
    print(f"  Индексы: {result['indices']}")
    print(f"  Расстояния: {result['distances']}")

plot_bestmatch_results(ts, query, mass_bestmatch_results['MASS1'])
plot_bestmatch_results(ts, query, mass_bestmatch_results['MASS2'])
plot_bestmatch_results(ts, query, mass_bestmatch_results['MASS3'])
# Out:
# Brute force: [1215, 193] [5.01641797172885, 18.030850173768776]
#
# MASS1:
#   Индексы: [1214, 192]
#   Расстояния: [5.016417971728851, 18.03085017376877]
#
# MASS2:
#   Индексы: [1215, 193]
#   Расстояния: [5.016417971728845, 18.030850173768773]
#
# MASS3:
#   Индексы: [1215, 193]
#   Расстояния: [5.016417971728822, 18.030850173768773]
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id
z4vy7\u002fIf32df2\u002fgQTFjzF3AMAdWmQ7308BwLdif9k9+QDAYqHWNO84\u002fr9LWYY41sX2v7MMcayL2+a\u002fgnNGlPYGxz9qTfOOU3TyP2iz6nO1FQBAvsEXJlMFBECjI7n8h3QCQAMJih9j7vA\u002f6Ugu\u002fyH9+b\u002f129eBc0YYwNxGA3gLBCnAowG8BRIENcAy5q4l5KM\u002fwEw3iUFgLUbAI0p7gy+MTcAoDwu1pulSwH6MuWsJbVfA\u002fYf029c1XMC5\u002fIf02wVhwO2ePCzUrGPAy6FFtvP9ZcB\u002f2T15WOhnwFYOLbKdX2nA6Ugu\u002fyFjasDY8PRKWchqwPcGX5hMF2rAuECC4scIacAJG55eKaFnwHgLJCh+6GXAkxgEVg7lY8CjkjoBTZhhwO7rwDkjal7AS+oENBGeWcBvgQTFjyFVwDnWxW00BFHAak3zjlOcSsDByqFFthNEwGiR7Xw\u002f5TzApN++DpyDM8AE54wo7e0nwLraiv1ldxXAGsBbIEHxyz+HFtnO9xMTQNCzWfW5miBAKe0NvjC5JUCEns2qz1UpQJZDi2zn2ytA5\u002fup8dKtLUAy5q4l5CMvQL1SliGORTBAGQRWDi0SMUCLbOf7qREyQLprCfmgVzNAGXPXEvLxNECZu5aQD+o2QEvIBz2bRTlAl\u002f+Qfvv6O0DM7snDQv0+QFg5tMh2HkFATfOOU3TUQkAOLbKd77dEQBE2PL1SxkZA+THmriX8SECzDHGsi1tLQOXyH9Jv501AswxxrIszUEDu68A5I3JRQNEi2\u002fl+plJAPzVeuknYU0ADCYofY45VQJyiI7n8U1dAqaROQBMlWUBlGeJYFxdbQHQkl\u002f+QHl1ArIvbaAAvX0Dc14FzRpxgQHEbDeAtVmFAMZkqGJX6YUDy0k1iEIRiQF5LyAc972JAyJi7lpA5Y0AUP8bctWJjQDj4wmSqamNAcF8HzhlRY0DY8PRKWRZjQOzAOSNKvWJAWmQ7309JYkCHFtnO971hQHctIR\u002f0HGFAvw6cM6 ...

# %% [markdown]
# ### **Задача 3.**
#
# Проведите две серии экспериментов по сравнению быстродействия алгоритмов грубой силы и трех версий MASS:
# 1. на фиксированной длине запроса $m$ при изменяемой длине временного ряда $n$;
# 2. на фиксированной длине временного ряда $n$ при изменяемой длине запроса $m$.
#
# Все необходимые для проведения экспериментов функции находятся в модуле *experiments.py*.
#
# Сначала сгенерируйте по аналогии временные ряды и запросы поиска различных длин, как это было сделано в практической работе 1. Далее измерьте время выполнения алгоритмов при заданных входных параметрах и данных с помощью функции `run_experiment()`. Полученные результаты (время выполнения) каждого эксперимента отобразите на линейном графике, воспользовавшись функцией `visualize_plot_times()`.
#
# Также вычислите ускорение с помощью функции `calculate_speedup()`, показывающее, во сколько раз алгоритм MASS превосходит по времени выполнения алгоритма грубой силы, по следующей формуле:
# \begin{equation}
# speedup = \frac{t_{BF}}{t_{MASS}},
# \end{equation}
# где $t_{BF}$ и $t_{MASS}$ — время работы алгоритма грубой силы и MASS соответственно.
#
# Полученные ускорения оформите в виде таблицы, для построения используйте функцию `visualize_table_speedup()`.

# %% [markdown]
# Эксперимент 1

# %%
algorithms = ['brute_force', 'mass', 'mass2', 'mass3']
algorithms_params = {
    'brute_force': None,
    'mass': None,
    'mass2': None,
    'mass3': {'segment_len': 2048},
}

n_list = [2**15, 2**16, 2**17, 2**18, 2**19, 2**20] # lengths of time series
m = 128 # length of query

exp1_params = {
    'varying': {'n': n_list},
    'fixed': {'m': m}
}

exp1_data = {
    'ts': dict.fromkeys(map(str, n_list), []),
    'query': {str(m): []}
}

task = 'distance_profile'

for n in n_list:
    exp1_data['ts'][str(n)] = random_walk(n)
exp1_data['query'][str(m)] = random_walk(m)

exp1_times = []
for algorithm in algorithms:
    alg_params = algorithms_params[algorithm]
    times = run_experiment(algorithm, task, exp1_data, exp1_params, alg_params)
    exp1_times.append(times)

exp1_times = np.array(exp1_times)   # shape (4, len(n_list))
print("exp1_times shape:", exp1_times.shape)
# Out:
# exp1_times shape: (4, 6)

# %%
# visualize plot with results of experiment
comparison_param = np.array(algorithms)

visualize_plot_times(exp1_times, comparison_param, exp1_params)
# Out:
# <div style="height:600px; width:1000px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id="0a4d2d80-c38a-4fd2-9013-e4d43c7a23a3" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0a4d2d80-c38a-4fd2-9013-e4d43c7a23a3")) {                    Plotly.newPlot(                        "0a4d2d80-c38a-4fd2-9013-e4d43c7a23a3",                        [{"line":{"width":3},"name":"brute_force","x":{"dtype":"i4","bdata":"AIAAAAAAAQAAAAIAAAAEAAAACAAAABAA"},"y":{"dtype":"f8","bdata":"AGDGUn\u002fY\u002fz8A4ANdVrwOQAD0uX\u002fRFiBAAEDUx40ILkAAPLAtTVU+QAAEPj+ML05A"},"type":"scatter"},{"line":{"width":3},"name":"mass","x":{"dtype":"i4","bdata":"AIAAAAAAAQAAAAIAAAAEAAAACAAAABAA"},"y":{"dtype":"f8","bdata":"AACwLQPOgj8AACjTwyuUPwAAAHA2Z6Y\u002fAADYyAlutz8AAMzitJbIPwAAZqGd09s\u002f"},"type":"scatter"},{"line":{"width":3},"name":"mass2","x":{"dtype":"i4","bdata":"AIAAAAAAAQAAAAIAAAAEAAAACAAAABAA"},"y":{"dtype":"f8","bdata":"AAAQA24nmz8AAFT2p56uPwAAnF8ou7w\u002fAACBqhs5yz8AAMxiYnPcPwBAuPe61uw\u002f"},"type":"scatter"},{"line":{"width":3},"name":"mass3","x":{"dtype":"i4","bdata":"AIAAAAAAAQAAAAIAAAAEAAAACAAAABAA"},"y":{"dtype":"f8","bdata":"AAAoGAG6nD8AAIR1iCSvPwAAvtmLDcA\u002fAIBj5NGy0D8AQOGE+DbkPwCw8InQAwBA"},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5 ...

# %%
# visualize table with speedup
tab_index = algorithms[1:]
tab_columns = [f"n = {n}" for n in n_list]
tab_title = "Speedup MASS relative to the brute force <br> (variable time series length, fixed query length)"

speedup = calculate_speedup(exp1_times[0], exp1_times[1:])
visualize_table_speedup(speedup, tab_index, tab_columns, tab_title)
# Out:
# <style type="text/css">
# #T_28fa5 th {
#   border: 1px black solid !important;
#   text-align: center;
# }
# #T_28fa5 caption {
#   font-size: 16px;
#   font-weight: bold;
#   padding: 10px 0px 10px 0px;
# }
# #T_28fa5_row0_col0, #T_28fa5_row0_col1, #T_28fa5_row0_col2, #T_28fa5_row0_col3, #T_28fa5_row0_col4, #T_28fa5_row0_col5, #T_28fa5_row1_col0, #T_28fa5_row1_col1, #T_28fa5_row1_col2, #T_28fa5_row1_col3, #T_28fa5_row1_col4, #T_28fa5_row1_col5, #T_28fa5_row2_col0, #T_28fa5_row2_col1, #T_28fa5_row2_col2, #T_28fa5_row2_col3, #T_28fa5_row2_col4, #T_28fa5_row2_col5 {
#   color: green;
#   border: 1px black solid !important;
#   text-align: center;
# }
# </style>
# <table id="T_28fa5">
#   <caption>Speedup MASS relative to the brute force <br> (variable time series length, fixed query length)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28fa5_level0_col0" class="col_heading level0 col0" >n = 32768</th>
#       <th id="T_28fa5_level0_col1" class="col_heading level0 col1" >n = 65536</th>
#       <th id="T_28fa5_level0_col2" class="col_heading level0 col2" >n = 131072</th>
#       <th id="T_28fa5_level0_col3" class="col_heading level0 col3" >n = 262144</th>
#       <th id="T_28fa5_level0_col4" class="col_heading level0 col4" >n = 524288</th>
#       <th id="T_28fa5_level0_col5" class="col_heading level0 col5" >n = 1048576</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28fa5_level0_row0" class="row_heading level0 row0" >mass</th>
#       <td id="T_28fa5_row0_col0" class="data row0 col0" >216.767131</td>
#       <td id="T_28fa5_row0_col1" class="data row0 col1" >195.041253</td>
#       <td id="T_28fa5_row0_col2" class="data row0 col2" >183.849765</td>
#       <td id="T_28fa5_row0_col3" class="data row0 col3" >164.076129</td>
#       <td id="T_28fa5_row0_col4" class="data row0 col4" >157.903879</td>
#       <td id="T_28fa5_row0_col5" class="data row0 col5" >138.851695</td>
#     </tr>
#     <tr>
#       <th id="T_28fa5_level0_row1" class="row_heading level0 row1" >mass2</th>
#       <td id="T_28fa5_row1_col0" class="data row1 col0" >75.057916</td>
#       <td id="T_28fa5_row1_col1" class="data row1 col1" >64.242337</td>
#       <td id="T_28fa5_row1_col2" class="data row1 col2" >71.678782</td>
#       <td id="T_28fa5_row1_col3" class="data row1 col3" >70.606947</td>
#       <td id="T_28fa5_row1_col4" class="data row1 col4" >68.234666</td>
#       <td id="T_28fa5_row1_col5" class="data row1 col5" >66.989181</td>
#     </tr>
#     <tr>
#       <th id="T_28fa5_level0_row2" class="row_heading level0 row2" >mass3</th>
#       <td id="T_28fa5_row2_col0" class="data row2 col0" >70.949079</td>
#       <td id="T_28fa5_row2_col1" class="data row2 col1" >63.163563</td>
#       <td id="T_28fa5_row2_col2" class="data row2 col2" >64.144398</td>
#       <td id="T_28fa5_row2_col3" class="data row2 col3" >57.554173</td>
#       <td id="T_28fa5_row2_col4" class="data row2 col4" >48.017594</td>
#       <td id="T_28fa5_row2_col5" class="data row2 col5" >30.157648</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Эксперимент 2

# %%
m_list = [2**5, 2**6, 2**7, 2**8, 2**9, 2**10] # lengths of queries
n = 2**15 # length of time series

exp2_params = {
    'varying': {'m': m_list},
    'fixed': {'n': n}
}

exp2_data = {
    'ts': {str(n): []},
    'query': dict.fromkeys(map(str, m_list), [])
}

exp2_data['ts'][str(n)] = random_walk(n)
for m_val in m_list:
    exp2_data['query'][str(m_val)] = random_walk(m_val)

exp2_times = []
for algorithm in algorithms:
    alg_params = algorithms_params[algorithm]
    times = run_experiment(algorithm, task, exp2_data, exp2_params, alg_params)
    exp2_times.append(times)

exp2_times = np.array(exp2_times)   # shape (4, len(m_list))
print("exp2_times shape:", exp2_times.shape)
# Out:
# exp2_times shape: (4, 6)

# %%
comparison_param = np.array(algorithms)

visualize_plot_times(exp2_times, comparison_param, exp2_params)
# Out:
# <div style="height:600px; width:1000px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id="a894c162-c9e2-41c1-be71-decdaa32b64d" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a894c162-c9e2-41c1-be71-decdaa32b64d")) {                    Plotly.newPlot(                        "a894c162-c9e2-41c1-be71-decdaa32b64d",                        [{"line":{"width":3},"name":"brute_force","x":{"dtype":"i4","bdata":"IAAAAEAAAACAAAAAAAEAAAACAAAABAAA"},"y":{"dtype":"f8","bdata":"AADys5Gr\u002fT8AIInnEYj+PwDg0Vos4P4\u002fAMCELGaf\u002fz8AsHnYVZIAQADgFizVtQFA"},"type":"scatter"},{"line":{"width":3},"name":"mass","x":{"dtype":"i4","bdata":"IAAAAEAAAACAAAAAAAEAAAACAAAABAAA"},"y":{"dtype":"f8","bdata":"AACw90Migz8AAIBzRpSGPwAA8CjwqYc\u002fAADg6PdYhT8AAFC\u002fImSFPwAA4EfP44Y\u002f"},"type":"scatter"},{"line":{"width":3},"name":"mass2","x":{"dtype":"i4","bdata":"IAAAAEAAAACAAAAAAAEAAAACAAAABAAA"},"y":{"dtype":"f8","bdata":"AAAwEJjihT8AAKg\u002fsQSQPwAAKEjHMJo\u002fAAAU3i+wqD8AAOT60ja3PwAAQyCXOMY\u002f"},"type":"scatter"},{"line":{"width":3},"name":"mass3","x":{"dtype":"i4","bdata":"IAAAAEAAAACAAAAAAAEAAAACAAAABAAA"},"y":{"dtype":"f8","bdata":"AACgVXd2gz8AAMA6x4CMPwAAyLH1DJk\u002fAAAAGXPXpj8AAGKpiZm2PwAArq6vGsk\u002f"},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line ...

# %%
tab_index = algorithms[1:]
tab_columns = [f"m = {m}" for m in m_list]
tab_title = "Speedup MASS relative to the brute force <br> (variable query length, fixed time series length)"

speedup = calculate_speedup(exp2_times[0], exp2_times[1:])
visualize_table_speedup(speedup, tab_index, tab_columns, tab_title)
# Out:
# <style type="text/css">
# #T_4c04e th {
#   border: 1px black solid !important;
#   text-align: center;
# }
# #T_4c04e caption {
#   font-size: 16px;
#   font-weight: bold;
#   padding: 10px 0px 10px 0px;
# }
# #T_4c04e_row0_col0, #T_4c04e_row0_col1, #T_4c04e_row0_col2, #T_4c04e_row0_col3, #T_4c04e_row0_col4, #T_4c04e_row0_col5, #T_4c04e_row1_col0, #T_4c04e_row1_col1, #T_4c04e_row1_col2, #T_4c04e_row1_col3, #T_4c04e_row1_col4, #T_4c04e_row1_col5, #T_4c04e_row2_col0, #T_4c04e_row2_col1, #T_4c04e_row2_col2, #T_4c04e_row2_col3, #T_4c04e_row2_col4, #T_4c04e_row2_col5 {
#   color: green;
#   border: 1px black solid !important;
#   text-align: center;
# }
# </style>
# <table id="T_4c04e">
#   <caption>Speedup MASS relative to the brute force <br> (variable query length, fixed time series length)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c04e_level0_col0" class="col_heading level0 col0" >m = 32</th>
#       <th id="T_4c04e_level0_col1" class="col_heading level0 col1" >m = 64</th>
#       <th id="T_4c04e_level0_col2" class="col_heading level0 col2" >m = 128</th>
#       <th id="T_4c04e_level0_col3" class="col_heading level0 col3" >m = 256</th>
#       <th id="T_4c04e_level0_col4" class="col_heading level0 col4" >m = 512</th>
#       <th id="T_4c04e_level0_col5" class="col_heading level0 col5" >m = 1024</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c04e_level0_row0" class="row_heading level0 row0" >mass</th>
#       <td id="T_4c04e_row0_col0" class="data row0 col0" >198.485127</td>
#       <td id="T_4c04e_row0_col1" class="data row0 col1" >173.081197</td>
#       <td id="T_4c04e_row0_col2" class="data row0 col2" >167.009658</td>
#       <td id="T_4c04e_row0_col3" class="data row0 col3" >189.609713</td>
#       <td id="T_4c04e_row0_col4" class="data row0 col4" >198.321937</td>
#       <td id="T_4c04e_row0_col5" class="data row0 col5" >198.071479</td>
#     </tr>
#     <tr>
#       <th id="T_4c04e_level0_row1" class="row_heading level0 row1" >mass2</th>
#       <td id="T_4c04e_row1_col0" class="data row1 col0" >173.532626</td>
#       <td id="T_4c04e_row1_col1" class="data row1 col1" >121.986345</td>
#       <td id="T_4c04e_row1_col2" class="data row1 col2" >75.448740</td>
#       <td id="T_4c04e_row1_col3" class="data row1 col3" >40.988150</td>
#       <td id="T_4c04e_row1_col4" class="data row1 col4" >22.843471</td>
#       <td id="T_4c04e_row1_col5" class="data row1 col5" >12.752074</td>
#     </tr>
#     <tr>
#       <th id="T_4c04e_level0_row2" class="row_heading level0 row2" >mass3</th>
#       <td id="T_4c04e_row2_col0" class="data row2 col0" >195.130849</td>
#       <td id="T_4c04e_row2_col1" class="data row2 col1" >137.109409</td>
#       <td id="T_4c04e_row2_col2" class="data row2 col2" >78.882000</td>
#       <td id="T_4c04e_row2_col3" class="data row2 col3" >44.301839</td>
#       <td id="T_4c04e_row2_col4" class="data row2 col4" >23.464497</td>
#       <td id="T_4c04e_row2_col5" class="data row2 col5" >11.287516</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ![equation.png](data:image/png;base64,...)
# Проанализируйте и изложите содержательный смысл полученных
# результатов.

# %% [markdown]
# По полученным результатам можно сделать вывод, что быстрее всех, работает алгоритм MASS, при увеличении как самого временного ряда, так и размера запроса, остальные алгоритмы полезны на небольших размерах ряда и запроса.

# %% [markdown]
# ## **Часть 2.** Ускорение вычисления DTW меры техникой ограничения полосы Сако—Чиба. Наивный алгоритм поиска по образцу на основе DTW меры.

# %% [markdown]
# ### **Задача 4.**
#
# Поскольку DTW мера имеет квадратичную вычислительную сложность от
# длины временного ряда $O(n^2)$, то в данном задании вам предстоит реализовать технику ограничения полосы Сако–Чиба. Данная техника не позволяет отклоняться пути трансформации более чем на $r$ ячеек от диагонали матрицы трансформации и тем самым сокращает вычисление меры до $O(rn)$.
#
# Добавьте в функцию `DTW_distance()` из модуля *metrics.py* возможность ограничения полосы Сако—Чиба. Сравните результаты выполнения вашей реализации с результатами функции [`dtw_distance()`](https://www.sktime.net/en/stable/api_reference/auto_generated/sktime.distances.dtw_distance.html) из библиотеки *sktime*, задав различные значения параметра $r$ (например, от 0 до 1 с шагом 0.05).
#
# **Мера DTW с ограничением полосы Сако–Чиба** вычисляется следующим образом:
# \begin{equation}
# \text{DTW}(T_1, T_2) = d(n,n),
# \\ d(i,j) = (t_{1,i} - t_{2,j})^2 + \min \left\{
# 	\begin{array}{l l}
# 	d(i-1,j), \\
# 	d(i,j-1), \\
# 	d(i-1,j-1),
# 	\end{array}
# 	\right.
# \\ d(0,0)=0, \quad d(i,0)=d(0,j)=\infty, \quad  1 \leqslant i,j \leqslant n;
# \\ 0 \leqslant r \leqslant n-1, \quad j-r \leqslant i \leqslant j+r,
# \\ d(i,j) = \infty, \quad j+r < i < j-r.
# \end{equation}

# %%
def test_distances(dist1: float, dist2: float) -> None:
    """
    Check whether your distance function is implemented correctly

    Parameters
    ----------
    dist1 : distance between two time series calculated by sktime
    dist2 : distance between two time series calculated by your function
    """

    np.testing.assert_equal(round(dist1, 5), round(dist2, 5), 'Distances are not equal')

# %%
from sktime.distances import dtw_distance
from modules.metrics import DTW_distance

x = ts[:len(query)]
r_list = np.round(np.arange(0, 1.01, 0.05), 2)

print(f"{'r':>6} | {'my DTW':>14} | {'sktime':>14} | {'diff':>12}")
print("-" * 60)

for r in r_list:
    my_d = DTW_distance(x, query, r)
    sk_d = dtw_distance(x, query, window=float(r))

    print(
        f"{r:>6.2f} | "
        f"{my_d:>14.5f} | "
        f"{sk_d:>14.5f} | "
        f"{abs(my_d - sk_d):>12.8f}")

    test_distances(sk_d, my_d)
# Out:
#      r |         my DTW |         sktime |         diff
# ------------------------------------------------------------
#   0.00 |  1173931.47250 |  1173931.47250 |   0.00000000
# C:\Python311\Lib\site-packages\sktime\utils\numba\njit.py:6: UserWarning: No module named 'numba'. 'numba' is a soft dependency and not included in the base sktime installation. Please run: `pip install numba` to install the numba package. To install all soft dependencies, run: `pip install sktime[all_extras]`
#   if _check_soft_dependencies("numba", severity="warning"):
#   0.05 |  1170858.39653 |  1170858.39653 |   0.00000000
#   0.10 |  1170293.64456 |  1170293.64456 |   0.00000000
#   0.15 |  1169840.53785 |  1169840.53785 |   0.00000000
#   0.20 |  1169764.02113 |  1169764.02113 |   0.00000000
#   0.25 |  1169752.79776 |  1169752.79776 |   0.00000000
#   0.30 |  1169645.06048 |  1169645.06048 |   0.00000000
#   0.35 |  1169526.42556 |  1169526.42556 |   0.00000000
#   0.40 |  1169380.49883 |  1169380.49883 |   0.00000000
#   0.45 |  1169380.49883 |  1169380.49883 |   0.00000000
#   0.50 |  1168438.61432 |  1168438.61432 |   0.00000000
#   0.55 |  1168339.84110 |  1168339.84110 |   0.00000000
#   0.60 |  1168339.84110 |  1168339.84110 |   0.00000000
#   0.65 |  1168339.84110 |  1168339.84110 |   0.00000000
#   0.70 |  1168339.84110 |  1168339.84110 |   0.00000000
#   0.75 |  1168339.84110 |  1168339.84110 |   0.00000000
#   0.80 |  1168339.84110 |  1168339.84110 |   0.00000000
#   0.85 |  1168339.84110 |  1168339.84110 |   0.00000000
#   0.90 |  1168339.84110 |  1168339.84110 |   0.00000000
#   0.95 |  1168339.84110 |  1168339.84110 |   0.00000000
#   1.00 |  1168339.84110 |  1168339.84110 |   0.00000000

# %% [markdown]
# ### **Задача 5.**
#
# Реализуйте самостоятельно наивный алгоритм поиска $topK$ подпоследовательностей временного ряда, похожих на образец поиска в смысле меры DTW. Для этого уже подготовлен шаблон класса `NaiveBestMatchFinder` в модуле *bestmatch.py*. Напишите метод `perform()`, выполняющий обнаружение подпоследовательностей ряда, похожих на образец поиска. Метод должен избегать попадания в результирующее множество пересекающихся подпоследовательностей. Для этого используйте функцию `topK_match()`. При реализации опирайтесь на псевдокод наивного алгоритма поиска, который представлен ниже.
#
# <center><img src="https://github.com/mzym/TimeSeriesCourse/blob/main/practice/02%20Similarity%20search/img/naive_algorithm.png?raw=true" width="550"></center>
#
# Для этой задачи используйте временной ряд и запрос ЭКГ из части 1. Если они не загружены, то выполните их считывание из соответствующих файлов.

# %%
topK = 2
r = 0.01
excl_zone_frac = 0.5
is_normalize = True

naive_bestmatch_results = {}

naive_dtw = NaiveBestMatchFinder(
    excl_zone_frac=excl_zone_frac,
    topK=topK,
    is_normalize=is_normalize,
    r=r
)

naive_bestmatch_results = naive_dtw.perform(ts, query)

print("Indices:", naive_bestmatch_results['indices'])
print("Distances:", naive_bestmatch_results['distances'])
# Out:
# Indices: [1214, 192]
# Distances: [13.926217775336447, 192.9575116412412]

# %% [markdown]
# Чтобы было легче интерпретировать результаты поиска, выполните визуализацию с помощью `plot_bestmatch_results()` из модуля *plots.py*.

# %%
plot_bestmatch_results(ts, query, naive_bestmatch_results)
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id="db44462f-ba97-498e-9497-4b155a11168e" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("db44462f-ba97-498e-9497-4b155a11168e")) {                    Plotly.newPlot(                        "db44462f-ba97-498e-9497-4b155a11168e",                        [{"line":{"color":"#EF553B"},"x":{"dtype":"i4","bdata":"...\\u002fAAAAP0AAAD+AAAA\...\u002fAQAAgAEAAIEBAACCAQAAgwEAAIQBAACFAQAAhgEAAIcBAACIAQAAiQEAAIoBAACLAQAAjAEAAI0BAACOAQAAjwEAAJABAACRAQAAkgEAAJMBAACUAQAAlQEAAJYBAACXAQAAmAEAAJkBAACaAQAAmwEAAJwBAACdAQAAngEAAJ8BAACgAQAAoQEAAKIBAACjAQAApAEAAA=="},"y":{"dtype":"f8","bdata":"5x2n6Egu9j9SSZ2AJsL7P8uhRbbzfQFA0ZFc\u002fkP6BUAy5q4l5AMOQIEmwoanFxRARIts5\u002fvpGUBv8IXJVAEgQCS5\u002fIf0+yJAnzws1JqmJUB4eqUsQ7wnQLdif9k9+ShAseHplbIsKUBhMlUwKkkoQKjGSzeJYSZA6+I2GsCbI0CNl24SgyAgQBsv3SQGQRhAF0hQ\u002fBhzD0DxY8xdS8j8P1wgQfFjzM2\u002fm1Wfq63YAMAW+8vuyUMOwAMJih9j7hTA4JwRpb3BGcARNjy9UpYdwK7YX3ZPPiDAhXzQs1lVIcD6fmq8dDMiwJayDHGs6yLA8fRKWYZ4I8C\u002fDpwzotQjwG3n+6nxEiTAPnlYqDVNJMAOvjCZKngkwDEIrBxahCTAjgbwFkhwJMAH8BZIUBwkwKCJsOHp1SPAyeU\u002fpN++IsCSy39Iv30fwO2ePCzUGg
DByqFFthNEwGiR7Xw\u002f5TzApN++DpyDM8AE54wo7e0nwLraiv1ldxXAGsBbIEHxyz+HFtnO9xMTQNCzWfW5miBAKe0NvjC5JUCEns2qz1UpQJZDi2zn2ytA5\u002fup8dKtLUAy5q4l5CMvQL1SliGORTBAGQRWDi0SMUCLbOf7qREyQLprCfmgVzNAGXPXEvLxNECZu5aQD+o2QEvIBz2bRTlAl\u002f+Qfvv6O0DM7snDQv0+QFg5tMh2HkFATfOOU3TUQkAOLbKd77dEQBE2PL1SxkZA+THmriX8SECzDHGsi1tLQOXyH9Jv501AswxxrIszUEDu68A5I3JRQNEi2\u002fl+plJAPzVeuknYU0ADCYofY45VQJyiI7n8U1dAqaROQBMlWUBlGeJYFxdbQHQkl\u002f+QHl1ArIvbaAAvX0Dc14FzRpxgQHEbDeAtVmFAMZkqGJX6YUDy0k1iEIRiQF5LyAc972JAyJi7lpA5Y0AUP8bctWJjQDj4wmSqamNAcF8HzhlRY0DY8PRKWRZjQOzAOSNKvWJAWmQ7309JYkCHFtnO971hQHctIR\u002f0HGFAvw6cM6 ...

# %% [markdown]
# ### **Задача 6**.
#
# Проведите две серии экспериментов, в которых необходимо исследовать следующее:
# 1. влияние длины запроса $m$ и ширины полосы Сако—Чиба $r$ на время выполнения наивного алгоритма при фиксированной длине ряда $n$;
# 2. влияние длины ряда $n$ и ширины полосы Сако—Чиба $r$ на время выполнения наивного алгоритма при фиксированной длине запроса $m$.
#
# Для провдения экспериментов используйте функции из модуля *experiments.py*.
# Эксперименты проведите на синтетических временных рядах и запросах указанных длин. Полученные результаты каждого эксперимента отобразите на линейном графике.

# %% [markdown]
# Эксперимент 1

# %%
algorithm = 'naive'
algorithm_params = {
    'topK': 3,
    'excl_zone_frac': 1,
    'normalize': True,
}

n_list = [2**10, 2**11, 2**12, 2**13, 2**14, 2**15] # lengths of time series
r_list = np.round(np.arange(0, 0.6, 0.1), 2).tolist() # sizes of warping window
m = 2**6 # length of query

exp1_params = {
    'varying': {'n': n_list,
                'r': r_list},
    'fixed': {'m': m}
}
exp1_data = {
    'ts': dict.fromkeys(map(str, n_list), []),
    'query': {str(m): []}
}

task = 'best_match'

# Генерация данных
for n in n_list:
    exp1_data['ts'][str(n)] = random_walk(n)
exp1_data['query'][str(m)] = random_walk(m)

# Запуск
exp1_times = run_experiment(algorithm, task, exp1_data, exp1_params, algorithm_params)
print("exp1_times shape:", exp1_times.shape)  # ожидаем (len(r_list), len(n_list))
exp1_times_naive = exp1_times.copy()
# Out:
# exp1_times shape: (6, 6)

# %%
# visualize plot with results of experiment
comparison_param = np.array(r_list)

visualize_plot_times(exp1_times, comparison_param, exp1_params)
# Out:
# <div style="height:600px; width:1000px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id="e7c2d7a0-2a5b-433d-a24d-103d3647998c" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e7c2d7a0-2a5b-433d-a24d-103d3647998c")) {                    Plotly.newPlot(                        "e7c2d7a0-2a5b-433d-a24d-103d3647998c",                        [{"line":{"width":3},"name":"0.0","x":{"dtype":"i4","bdata":"AAQAAAAIAAAAEAAAACAAAABAAAAAgAAA"},"y":{"dtype":"f8","bdata":"AADkv0AQxD8AgI3O+anVPwDA5VE7jeQ\u002fAGDKxt6m9D8AEMWrrA0GQABo8zgMThVA"},"type":"scatter"},{"line":{"width":3},"name":"0.1","x":{"dtype":"i4","bdata":"AAQAAAAIAAAAEAAAACAAAABAAAAAgAAA"},"y":{"dtype":"f8","bdata":"AMDCZRU26T8AgGDBouf5PwCA0xYyYglAACBnP\u002ffiGUAAQKZ8COoqQAAooImwCTpA"},"type":"scatter"},{"line":{"width":3},"name":"0.2","x":{"dtype":"i4","bdata":"AAQAAAAIAAAAEAAAACAAAABAAAAAgAAA"},"y":{"dtype":"f8","bdata":"AKCValWh9D8AENRAmGAFQACos+56pBVAANBBl3AgJkAAvqmjPmA2QADZ02k4PkdA"},"type":"scatter"},{"line":{"width":3},"name":"0.3","x":{"dtype":"i4","bdata":"AAQAAAAIAAAAEAAAACAAAABAAAAAgAAA"},"y":{"dtype":"f8","bdata":"AIBZuFEJ\u002fj8AYMVfSQgPQADQMwdSix9AAOTEVzswMEAA4COs11hAQAAW\u002fDbEp09A"},"type":"scatter"},{"line":{"width":3},"name":"0.4","x":{"dtype":"i4","bdata":"AAQAAAAIAAAAEAAAACAAAABAAAAAgAAA"},"y":{"dtype":"f8","bdata":"AAD1IiRMAkAAKH\u002f3jhITQACgtCbM0iNAABgR1hCiM0AArbR7qGxDQIDf4dEhrlNA"},"type":"scatter"},{"line":{"width":3},"name":"0.5","x":{"dtype":"i4","bdata":"AAQAAAAIAAAAEAAAACAAAABAAAAAgAAA"},"y":{"dtype":"f8","bdata":"AHCIY128BUAAGB2hsDUWQAAk9UMRlyZAANrXywB\u002fNkAAMoJ8v8VGQIAKDi8I3VZA"},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth ...

# %% [markdown]
# Эксперимент 2

# %%
m_list = [2**4, 2**5, 2**6, 2**7, 2**8] # lengths of query
r_list = np.round(np.arange(0, 0.6, 0.1), 2).tolist() # sizes of warping window
n = 2**12 # length of time series

exp2_params = {
    'varying': {'m': m_list,
                'r': r_list},
    'fixed': {'n': n}
}
exp2_data = {
    'ts': {str(n): []},
    'query': dict.fromkeys(map(str, m_list), []),
}

exp2_data['ts'][str(n)] = random_walk(n)
for m_val in m_list:
    exp2_data['query'][str(m_val)] = random_walk(m_val)

exp2_times = run_experiment(algorithm, task, exp2_data, exp2_params, algorithm_params)
print("exp2_times shape:", exp2_times.shape)

exp2_times_naive = exp2_times.copy()
# Out:
# exp2_times shape: (6, 5)

# %%
comparison_param = np.array(r_list)

visualize_plot_times(exp2_times, comparison_param, exp2_params)
# Out:
# <div style="height:600px; width:1000px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id="43693e4d-a1f4-423e-a454-0428e1721cdd" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("43693e4d-a1f4-423e-a454-0428e1721cdd")) {                    Plotly.newPlot(                        "43693e4d-a1f4-423e-a454-0428e1721cdd",                        [{"line":{"width":3},"name":"0.0","x":{"dtype":"i4","bdata":"EAAAACAAAABAAAAAgAAAAAABAAA="},"y":{"dtype":"f8","bdata":"AIA4B3RL3z8AAGN7LejcPwCASl0yDuQ\u002fAEC4aBJG7z8AoLbUQf76Pw=="},"type":"scatter"},{"line":{"width":3},"name":"0.1","x":{"dtype":"i4","bdata":"EAAAACAAAABAAAAAgAAAAAABAAA="},"y":{"dtype":"f8","bdata":"AIBgJkCD3T8AoLkKc0zxPwBA1\u002f2+iglAADzaOGLxJUAAPpnarQ9FQA=="},"type":"scatter"},{"line":{"width":3},"name":"0.2","x":{"dtype":"i4","bdata":"EAAAACAAAABAAAAAgAAAAAABAAA="},"y":{"dtype":"f8","bdata":"AIAHmb8d5T8AQDry9nb6PwDg+lUlPhZAAOxeOCHQNECA9nOvuCFUQA=="},"type":"scatter"},{"line":{"width":3},"name":"0.3","x":{"dtype":"i4","bdata":"EAAAACAAAABAAAAAgAAAAAABAAA="},"y":{"dtype":"f8","bdata":"AEAOsKD65z8AwA6FKvABQADouTsh+h9AAEJBhBNsPkAAVSHUe2VcQA=="},"type":"scatter"},{"line":{"width":3},"name":"0.4","x":{"dtype":"i4","bdata":"EAAAACAAAABAAAAAgAAAAAABAAA="},"y":{"dtype":"f8","bdata":"AADrmKk\u002f7T8A0JvlDYsFQABsonSO\u002fiNAAGIRww40Q0AAyjSanMFhQA=="},"type":"scatter"},{"line":{"width":3},"name":"0.5","x":{"dtype":"i4","bdata":"EAAAACAAAABAAAAAgAAAAAABAAA="},"y":{"dtype":"f8","bdata":"AKCVFXnI8D8A0BLn8qAJQAAwZgHJVidAAJyY5Db6RUBAgSOBhhplQA=="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solid ...

# %% [markdown]
# ![equation.png](data:image/png;base64,...)
# Проанализируйте и изложите содержательный смысл полученных
# результатов.

# %% [markdown]
# Из экспериментов видно влияние ограничения полосы Сако—Чиба на вычислительную сложность DTW. Чем сильнее ограничивается область поиска пути, тем меньше элементов матрицы необходимо вычислять, поэтому алгоритм может работать быстрее.
#
# При этом увеличение длины временного ряда или длины запроса увеличивает количество вычислений и, соответственно, время работы алгоритма.

# %% [markdown]
# ## **Часть 3.** Алгоритм UCR-DTW.
#
# Третья часть практической работы посвящена алгоритму UCR-DTW, который использует нижние границы схожести $\text{LB}_{\text{Kim}}\text{FL}$, $\text{LB}_{\text{Keogh}}\text{EQ}$ и $\text{LB}_{\text{Keogh}}\text{EC}$, применяющиеся каскадным образом. Псевдокод алгоритма UCR-DTW представлен ниже.
#
# <center><img src="https://github.com/mzym/TimeSeriesCourse/blob/main/practice/02%20Similarity%20search/img/ucr_dtw.png?raw=true" width="650"></center>
#
# **Нижняя граница схожести (lower bound, LB)** представляет собой функцию, вычислительная сложность которой меньше вычислительной сложности меры DTW. Нижняя граница используется для отбрасывания кандидатов (подпоследовательностей временного ряда), заведомо не похожих на запрос, без вычисления меры DTW.
#
# Нижние границы между кандидатом
# $C$ и запросом $Q$ длины $n$, применяемые в UCR-DTW, вычисляются следующим образом:
# <ul>
# <li><b>Нижняя граница $\text{LB}_{\text{Kim}}\text{FL}$</b> определяется как сумма квадратов разностей между первыми и последними точками запроса $Q$ и
# подпоследовательности $C$:
# \begin{equation}
#     \text{LB}_{\text{Kim}}\text{FL}(Q, C) = (q_1 - c_1)^2 + (q_n - c_n)^2.
# \end{equation}
# </li>
#
# <li><b>Нижняя граница $\text{LB}_{\text{Keogh}}\text{EQ}$</b> показывает расстояние между верхней или нижней оболочкой $U$ и $L$, построенными вокруг запроса $Q$, и кандидатом $C$:
# \begin{equation}
#     \text{LB}_{\text{Keogh}}\text{EQ}(Q,C) = \sum_{i=1}^n{\left\{
#             \begin{array}{cl}
#             (c_i - u_i)^2, & \text{if} \; c_i > u_i \\
#             (c_i - l_i)^2, & \text{if} \; c_i < l_i\\
#             0, & \text{otherwise}.
#             \end{array}
#             \right.}
# \end{equation}
#
# Нижней и верхней оболочкой (lower and upper envelope) запроса $Q$ называют соответственно последовательности $L = (l_1,..., l_n)$ и $U = (u_1,..., u_n)$, вычисляемые как минимумы и максимумы запроса в скользящем окне заданной длины $r$ ($1 < r < m$):
# \begin{equation}
#     u_i = \max_{\max(1,i-r) \leqslant k \leqslant \min(m, i+r)} q_{k}, \\
#     l_i = \min_{\max(1,i-r) \leqslant k \leqslant \min(m, i+r)} q_{k},
# \end{equation}
# где $r$ – ширина полосы Сако–Чиба.
# </li>
#
# <li><b>Нижняя граница $\text{LB}_{\text{Keogh}}\text{EC}$</b> представляет собой расстояние между запросом $Q$ и оболочкой кандидата $C$, т.е. является реверс-версией нижней границы $\text{LB}_{\text{Keogh}}\text{EQ}$:
# \begin{equation}
#     \text{LB}_{\text{Keogh}}\text{EC}(Q,C) = \text{LB}_{\text{Keogh}}\text{EQ}(C, Q).
# \end{equation}
# </li>
# </ul>

# %% [markdown]
# ### **Задача 7.**
#
# Реализуйте технику каскадного применения нижних границ и сами нижние границы,  заполнив пропуски в классе `UCR_DTW`, в модуле *bestmatch.py*.
# Выполните алгоритм UCR-DTW на данных ЭКГ из предыдущих частей, задав такие же значения входных параметров, что и для наивного алгоритма из части 2, и визуализируйте результаты. Убедитесь, что результаты UCR-DTW совпадают с результатами наивного алгоритма.

# %%
top_k = 2
r = 0.01
excl_zone_frac = 1
is_normalize = True

ucr_dtw_results = {}

ucr_dtw = UCR_DTW(
    excl_zone_frac=excl_zone_frac,
    topK=top_k,
    is_normalize=is_normalize,
    r=r
)

ucr_dtw_results = ucr_dtw.perform(ts, query)

print("UCR-DTW:")
print("Индексы:", ucr_dtw_results['indices'])
print("Расстояния:", ucr_dtw_results['distances'])

print("\nNaive DTW:")
print("Индексы:", naive_bestmatch_results['indices'])
print("Расстояния:", naive_bestmatch_results['distances'])

plot_bestmatch_results(ts, query, ucr_dtw_results)
# Out:
# UCR-DTW:
# Индексы: [1214, 192]
# Расстояния: [13.926217775336447, 192.9575116412412]
#
# Naive DTW:
# Индексы: [1214, 192]
# Расстояния: [13.926217775336447, 192.9575116412412]
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id="39c16db6-d588-450b-850a-f9bb97d6caa5" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("39c16db6-d588-450b-850a-f9bb97d6caa5")) {                    Plotly.newPlot(                        "39c16db6-d588-450b-850a-f9bb97d6caa5",                        [{"line":{"color":"#EF553B"},"x":{"dtype":"i4","bdata":"...\\u002fAAAAP0AAAD+AAAA\...\u002fAQAAgAEAAIEBAACCAQAAgwEAAIQBAACFAQAAhgEAAIcBAACIAQAAiQEAAIoBAACLAQAAjAEAAI0BAACOAQAAjwEAAJABAACRAQAAkgEAAJMBAACUAQAAlQEAAJYBAACXAQAAmAEAAJkBAACaAQAAmwEAAJwBAACdAQAAngEAAJ8BAACgAQAAoQEAAKIBAACjAQAApAEAAA=="},"y":{"dtype":"f8","bdata":"5x2n6Egu9j9SSZ2AJsL7P8uhRbbzfQFA0ZFc\u002fkP6BUAy5q4l5AMOQIEmwoanFxRARIts5\u002fvpGUBv8IXJVAEgQCS5\u002fIf0+yJAnzws1JqmJUB4eqUsQ7wnQLdif9k9+ShAseHplbIsKUBhMlUwKkkoQKjGSzeJYSZA6+I2GsCbI0CNl24SgyAgQBsv3SQGQRhAF0hQ\u002fBhzD0DxY8xdS8j8P1wgQfFjzM2\u002fm1Wfq63YAMAW+8vuyUMOwAMJih9j7hTA4JwRpb3BGcARNjy9UpYdwK7YX3ZPPiDAhXzQs1lVIcD6fmq8dDMiwJayDHGs6yLA8fRKWYZ4I8C\u002fDpwzotQjwG3n+6nxEiTAPnlYqDVNJMAOvjCZKngkwDEIrBxahCTAjgbwFkhwJMAH8BZIUBwkwKCJsOHp1SPAyeU\u002fpN++IsCSy39Iv30fwO2ePCzUGgHAescpOpJLJUC+wRcmU1U+QJhMFYxKkkpAM8SxLm4bUkB3LSEf9PxUQM07TtGRpFVAEqW9wRcGVEAAAAAAAEBQQN21hHzQc0ZAidLe4AvDNUBIv30dOOcAQKTfvg6ccyTAUwWjkjpBLcDAWyBB8cMrwDhnRGlvsCbAirDh6ZVSJcDD9Shcj6IkwEXY8PRK2STAsi5uowHcJMDFjzF3LcEkwK36XG3F\u002fiTAc2iR7XxfJcAqOpLLf4glwBUdyeU\u002fJCXAMlUwKqmTI8AmUwWjkvohwEATYcPTSyDAEhQ\u002fxtx1HcAJG55eKcsawDSAt0CCohjAcM6I0t7gFsCEDU+vlGUVwLRZ9bnaChTA46WbxCCwEsBfmEwVjEoRwDGZKhiV1A\u
# %% [markdown]
# Визуализируйте количество неотброшенных и отброшенных каждой нижней границей подпоследовательностей временного ряда в виде круговой диаграммы с помощью функции `pie_chart()` из модуля *plots.py*.

# %%
statistics = ucr_dtw.get_statistics()

print(statistics)

labels = np.array([
    'LB_Kim',
    'LB_Keogh EQ',
    'LB_Keogh EC',
    'DTW'
])

values = np.array([
    statistics['lb_Kim_num'],
    statistics['lb_KeoghQC_num'],
    statistics['lb_KeoghCQ_num'],
    statistics['not_pruned_num']
])

pie_chart(
    labels,
    values,
    'UCR-DTW pruning statistics'
)
# Out:
# {'not_pruned_num': 47, 'lb_Kim_num': 50, 'lb_KeoghCQ_num': 0, 'lb_KeoghQC_num': 2483}
# <div style="height:500px; width:700px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id="e76be17d-a2d3-456d-b5c9-e67e6b53cd15" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e76be17d-a2d3-456d-b5c9-e67e6b53cd15")) {                    Plotly.newPlot(                        "e76be17d-a2d3-456d-b5c9-e67e6b53cd15",                        [{"labels":["LB_Kim","LB_Keogh EQ","LB_Keogh EC","DTW"],"values":{"dtype":"i4","bdata":"MgAAALMJAAAAAAAALwAAAA=="},"type":"pie","textfont":{"size":20}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scattermap":[{"type":"scattermap","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterternary":[{"type":"scattertern ...
#
# var gd = document.getElementById('e76be17d-a2d

# %% [markdown]
# ### **Задача 8.**
#
# Проведите эксперименты, аналогичные тем, которые выполнялись для исследования эффективности наивного алгоритма в задаче 6. Постройте графики и вычислите ускорение алгоритма UCR-DTW относительно наивного алгоритма. Для справедливого сравнения алгоритмов используйте сгенерированные временные ряды и запросы из задачи 6.

# %% [markdown]
# Эксперимент 1

# %%
algorithm = 'ucr-dtw'
algorithm_params = {
    'topK': 3,
    'excl_zone_frac': 1,
    'normalize': True,
}

n_list = [2**10, 2**11, 2**12, 2**13, 2**14, 2**15] # lengths of time series
r_list = np.round(np.arange(0, 0.6, 0.1), 2).tolist() # sizes of warping window
m = 2**6 # length of query

exp1_params = {
    'varying': {'n': n_list,
                'r': r_list},
    'fixed': {'m': m}
}
exp1_data = {
    'ts': dict.fromkeys(map(str, n_list), []),
    'query': {str(m): []}
}

task = 'best_match'

# generate set of time series and query
# run experiments for measurement of algorithm runtimes

for n in n_list:
    exp1_data['ts'][str(n)] = random_walk(n)

exp1_data['query'][str(m)] = random_walk(m)

exp1_times = run_experiment(
    algorithm,
    task,
    exp1_data,
    exp1_params,
    algorithm_params
)

print("exp1_times shape:", exp1_times.shape)
# Out:
# exp1_times shape: (6, 6)

# %%
#visualize plot with results of experiment
comparison_param = np.array(r_list)

visualize_plot_times(
    exp1_times,
    comparison_param,
    exp1_params
)
# Out:
# <div style="height:600px; width:1000px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id="05cd972a-bd5d-4ffa-84c0-5fc9775340a1" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("05cd972a-bd5d-4ffa-84c0-5fc9775340a1")) {                    Plotly.newPlot(                        "05cd972a-bd5d-4ffa-84c0-5fc9775340a1",                        [{"line":{"width":3},"name":"0.0","x":{"dtype":"i4","bdata":"AAQAAAAIAAAAEAAAACAAAABAAAAAgAAA"},"y":{"dtype":"f8","bdata":"AMCbDq7K5D8A4EdXRKjxPwCA6kGcAgFAAMBMFCFtEEAACIuKOA0hQADohNBBay9A"},"type":"scatter"},{"line":{"width":3},"name":"0.1","x":{"dtype":"i4","bdata":"AAQAAAAIAAAAEAAAACAAAABAAAAAgAAA"},"y":{"dtype":"f8","bdata":"AMBLNh4s5z8AwPZr\u002fHPyPwDAXpoiQPg\u002fAHDZCvVPDUAAWP58W8AZQADMNRZeJyBA"},"type":"scatter"},{"line":{"width":3},"name":"0.2","x":{"dtype":"i4","bdata":"AAQAAAAIAAAAEAAAACAAAABAAAAAgAAA"},"y":{"dtype":"f8","bdata":"AAD\u002fBu2V7j8AwLNOpvv0PwBQ+FvxgwFAALDG2XQUFEAAhGFl2TwhQACsrFxeryhA"},"type":"scatter"},{"line":{"width":3},"name":"0.3","x":{"dtype":"i4","bdata":"AAQAAAAIAAAAEAAAACAAAABAAAAAgAAA"},"y":{"dtype":"f8","bdata":"AOC02mgF+z8AUJrClPIBQACAd2Ss9gxAAHC1geCuHEAAkCJrDc0qQAD2q0psbDFA"},"type":"scatter"},{"line":{"width":3},"name":"0.4","x":{"dtype":"i4","bdata":"AAQAAAAIAAAAEAAAACAAAABAAAAAgAAA"},"y":{"dtype":"f8","bdata":"ALDOjNldAEAAMFqzOs4HQAAoA0AV1xNAADBdd6nfJEAADFZBsb4zQAAqpQzBbDhA"},"type":"scatter"},{"line":{"width":3},"name":"0.5","x":{"dtype":"i4","bdata":"AAQAAAAIAAAAEAAAACAAAABAAAAAgAAA"},"y":{"dtype":"f8","bdata":"AJB\u002fmZSHAkAAYBbJDVUNQAAYrmk5qxlAABx5ILJ8KkAADFcHQGY4QAC3XWiu2UFA"},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks ...

# %%
# visualize table with speedup
tab_index = [f"n = {n}" for n in n_list]
tab_columns = [f"r = {r}" for r in r_list]
tab_title = "Speedup UCR-DTW relative to the naive algorithm <br> (variable time series length and warping path size, fixed query length)"

speedup = calculate_speedup(
    exp1_times_naive,
    exp1_times
)

visualize_table_speedup(
    speedup,
    tab_index,
    tab_columns,
    tab_title
)
# Out:
# <style type="text/css">
# #T_a43ca th {
#   border: 1px black solid !important;
#   text-align: center;
# }
# #T_a43ca caption {
#   font-size: 16px;
#   font-weight: bold;
#   padding: 10px 0px 10px 0px;
# }
# #T_a43ca_row0_col0, #T_a43ca_row0_col1, #T_a43ca_row0_col2, #T_a43ca_row0_col3, #T_a43ca_row0_col4, #T_a43ca_row0_col5 {
#   color: red;
#   border: 1px black solid !important;
#   text-align: center;
# }
# #T_a43ca_row1_col0, #T_a43ca_row1_col1, #T_a43ca_row1_col2, #T_a43ca_row1_col3, #T_a43ca_row1_col4, #T_a43ca_row1_col5, #T_a43ca_row2_col0, #T_a43ca_row2_col1, #T_a43ca_row2_col2, #T_a43ca_row2_col3, #T_a43ca_row2_col4, #T_a43ca_row2_col5, #T_a43ca_row3_col0, #T_a43ca_row3_col1, #T_a43ca_row3_col2, #T_a43ca_row3_col3, #T_a43ca_row3_col4, #T_a43ca_row3_col5, #T_a43ca_row4_col0, #T_a43ca_row4_col1, #T_a43ca_row4_col2, #T_a43ca_row4_col3, #T_a43ca_row4_col4, #T_a43ca_row4_col5, #T_a43ca_row5_col0, #T_a43ca_row5_col1, #T_a43ca_row5_col2, #T_a43ca_row5_col3, #T_a43ca_row5_col4, #T_a43ca_row5_col5 {
#   color: green;
#   border: 1px black solid !important;
#   text-align: center;
# }
# </style>
# <table id="T_a43ca">
#   <caption>Speedup UCR-DTW relative to the naive algorithm <br> (variable time series length and warping path size, fixed query length)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a43ca_level0_col0" class="col_heading level0 col0" >r = 0.0</th>
#       <th id="T_a43ca_level0_col1" class="col_heading level0 col1" >r = 0.1</th>
#       <th id="T_a43ca_level0_col2" class="col_heading level0 col2" >r = 0.2</th>
#       <th id="T_a43ca_level0_col3" class="col_heading level0 col3" >r = 0.3</th>
#       <th id="T_a43ca_level0_col4" class="col_heading level0 col4" >r = 0.4</th>
#       <th id="T_a43ca_level0_col5" class="col_heading level0 col5" >r = 0.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a43ca_level0_row0" class="row_heading level0 row0" >n = 1024</th>
#       <td id="T_a43ca_row0_col0" class="data row0 col0" >0.241244</td>
#       <td id="T_a43ca_row0_col1" class="data row0 col1" >0.306728</td>
#       <td id="T_a43ca_row0_col2" class="data row0 col2" >0.302050</td>
#       <td id="T_a43ca_row0_col3" class="data row0 col3" >0.314311</td>
#       <td id="T_a43ca_row0_col4" class="data row0 col4" >0.323333</td>
#       <td id="T_a43ca_row0_col5" class="data row0 col5" >0.339045</td>
#     </tr>
#     <tr>
#       <th id="T_a43ca_level0_row1" class="row_heading level0 row1" >n = 2048</th>
#       <td id="T_a43ca_row1_col0" class="data row1 col0" >1.087990</td>
#       <td id="T_a43ca_row1_col1" class="data row1 col1" >1.403822</td>
#       <td id="T_a43ca_row1_col2" class="data row1 col2" >2.093445</td>
#       <td id="T_a43ca_row1_col3" class="data row1 col3" >1.766259</td>
#       <td id="T_a43ca_row1_col4" class="data row1 col4" >2.090309</td>
#       <td id="T_a43ca_row1_col5" class="data row1 col5" >3.223747</td>
#     </tr>
#     <tr>
#       <th id="T_a43ca_level0_row2" class="row_heading level0 row2" >n = 4096</th>
#       <td id="T_a43ca_row2_col0" class="data row2 col0" >1.349012</td>
#       <td id="T_a43ca_row2_col1" class="data row2 col1" >2.037584</td>
#       <td id="T_a43ca_row2_col2" class="data row2 col2" >2.471254</td>
#       <td id="T_a43ca_row2_col3" class="data row2 col3" >2.203866</td>
#       <td id="T_a43ca_row2_col4" class="data row2 col4" >2.596166</td>
#       <td id="T_a43ca_row2_col5" class="data row2 col5" >3.766339</td>
#     </tr>
#     <tr>
#       <th id="T_a43ca_level0_row3" class="row_heading level0 row3" >n = 8192</th>
#       <td id="T_a43ca_row3_col0" class="data row3 col0" >1.111589</td>
#       <td id="T_a43ca_row3_col1" class="data row3 col1" >1.729056</td>
#       <td id="T_a43ca_row3_col2" class="data row3 col2" >2.178200</td>
#       <td id="T_a43ca_row3_col3" class="data row3 col3" >2.257552</td>
#       <td id="T_a43ca_row3_col4" class="data row3 col4" >2.439767</td>
#       <td id="T_a43ca_row3_col5" class="data row3 col5" >3.633631</td>
#     </tr>
#     <tr>
#       <th id="T_a43ca_level0_row4" class="row_heading level0 row4" >n = 16384</th>
#       <td id="T_a43ca_row4_col0" class="data row4 col0" >1.117974</td>
#       <td id="T_a43ca_row4_col1" class="data row4 col1" >1.602355</td>
#       <td id="T_a43ca_row4_col2" class="data row4 col2" >1.998312</td>
#       <td id="T_a43ca_row4_col3" class="data row4 col3" >1.881132</td>
#       <td id="T_a43ca_row4_col4" class="data row4 col4" >1.967541</td>
#       <td id="T_a43ca_row4_col5" class="data row4 col5" >3.222984</td>
#     </tr>
#     <tr>
#       <th id="T_a43ca_level0_row5" class="row_heading level0 row5" >n = 32768</th>
#       <td id="T_a43ca_row5_col0" class="data row5 col0" >1.173031</td>
#       <td id="T_a43ca_row5_col1" class="data row5 col1" >1.514356</td>
#       <td id="T_a43ca_row5_col2" class="data row5 col2" >1.760119</td>
#       <td id="T_a43ca_row5_col3" class="data row5 col3" >1.698647</td>
#       <td id="T_a43ca_row5_col4" class="data row5 col4" >1.866639</td>
#       <td id="T_a43ca_row5_col5" class="data row5 col5" >2.561681</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Эксперимент 2

# %%
m_list = [2**4, 2**5, 2**6, 2**7, 2**8] # lengths of query
r_list = np.round(np.arange(0, 0.6, 0.1), 2).tolist() # sizes of warping window
n = 2**12 # length of time series

exp_params = {
    'varying': {'m': m_list,
                'r': r_list},
    'fixed': {'n': n}
}
data = {
    'ts': {str(n): []},
    'query': dict.fromkeys(map(str, m_list), []),
}

data['ts'][str(n)] = random_walk(n)

for m_val in m_list:
    data['query'][str(m_val)] = random_walk(m_val)

exp2_times = run_experiment(
    algorithm,
    'best_match',
    data,
    exp_params,
    algorithm_params
)

print("exp2_times shape:", exp2_times.shape)
# Out:
# exp2_times shape: (6, 5)

# %%
comparison_param = np.array(r_list)

visualize_plot_times(
    exp2_times,
    comparison_param,
    exp_params
)
# Out:
# <div style="height:600px; width:1000px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/3.2.2/es5/tex-svg.min.js"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-4.1.1.min.js" integrity="sha256-O24V1F27f8pb0glCkelh3cVHLNiHAJ5gCaVtq2aNch8=" crossorigin="anonymous"></script>                <div id="81d3a0fe-481a-4248-a5ca-5fc9be5a1ccf" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("81d3a0fe-481a-4248-a5ca-5fc9be5a1ccf")) {                    Plotly.newPlot(                        "81d3a0fe-481a-4248-a5ca-5fc9be5a1ccf",                        [{"line":{"width":3},"name":"0.0","x":{"dtype":"i4","bdata":"EAAAACAAAABAAAAAgAAAAAABAAA="},"y":{"dtype":"f8","bdata":"AAAf\u002fYqQwT8AgN\u002fiPLftPwCgFpqQ+wBAAMhPLWxvEEAAVGnmJE8gQA=="},"type":"scatter"},{"line":{"width":3},"name":"0.1","x":{"dtype":"i4","bdata":"EAAAACAAAABAAAAAgAAAAAABAAA="},"y":{"dtype":"f8","bdata":"AACEF30Fvz8AgKu5klPmPwDwTuODEwFAAMj1gxVKEkAAoAAv2IIxQA=="},"type":"scatter"},{"line":{"width":3},"name":"0.2","x":{"dtype":"i4","bdata":"EAAAACAAAABAAAAAgAAAAAABAAA="},"y":{"dtype":"f8","bdata":"AABkbfiCvz8AAN4dGevvPwCwDFqjaQtAACRcyCPgIUAAZDGgzcxGQA=="},"type":"scatter"},{"line":{"width":3},"name":"0.3","x":{"dtype":"i4","bdata":"EAAAACAAAABAAAAAgAAAAAABAAA="},"y":{"dtype":"f8","bdata":"AAD2k3vLvj8AgPGlppPyPwD4s8RvPxNAAPC7jt0uK0AA0D77tkZVQA=="},"type":"scatter"},{"line":{"width":3},"name":"0.4","x":{"dtype":"i4","bdata":"EAAAACAAAABAAAAAgAAAAAABAAA="},"y":{"dtype":"f8","bdata":"AADaoswGvz8A4It5Zz72PwBgtdcn\u002fRlAAIJC8+\u002fpMUAAtfdOcZZeQA=="},"type":"scatter"},{"line":{"width":3},"name":"0.5","x":{"dtype":"i4","bdata":"EAAAACAAAABAAAAAgAAAAAABAAA="},"y":{"dtype":"f8","bdata":"AABmLQWkwD8AgHrBp\u002fn6PwDkVCHUdyFAAPjVwWYvOUAAWZjPQ5pjQA=="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10," ...

# %%
tab_index = [f"m = {m}" for m in m_list]
tab_columns = [f"r = {r}" for r in r_list]
tab_title = "Speedup UCR-DTW relative to the naive algorithm <br> (variable query length and warping path size, fixed time series length)"

speedup = calculate_speedup(
    exp2_times_naive,
    exp2_times
)

visualize_table_speedup(
    speedup,
    tab_columns,
    tab_index,
    tab_title
)
# Out:
# <style type="text/css">
# #T_2e1a4 th {
#   border: 1px black solid !important;
#   text-align: center;
# }
# #T_2e1a4 caption {
#   font-size: 16px;
#   font-weight: bold;
#   padding: 10px 0px 10px 0px;
# }
# #T_2e1a4_row0_col0, #T_2e1a4_row1_col0, #T_2e1a4_row1_col1, #T_2e1a4_row1_col2, #T_2e1a4_row1_col3, #T_2e1a4_row1_col4, #T_2e1a4_row2_col0, #T_2e1a4_row2_col1, #T_2e1a4_row2_col2, #T_2e1a4_row2_col3, #T_2e1a4_row2_col4, #T_2e1a4_row3_col0, #T_2e1a4_row3_col1, #T_2e1a4_row3_col2, #T_2e1a4_row3_col3, #T_2e1a4_row3_col4, #T_2e1a4_row4_col0, #T_2e1a4_row4_col1, #T_2e1a4_row4_col2, #T_2e1a4_row4_col3, #T_2e1a4_row4_col4, #T_2e1a4_row5_col0, #T_2e1a4_row5_col1, #T_2e1a4_row5_col2, #T_2e1a4_row5_col3, #T_2e1a4_row5_col4 {
#   color: green;
#   border: 1px black solid !important;
#   text-align: center;
# }
# #T_2e1a4_row0_col1, #T_2e1a4_row0_col2, #T_2e1a4_row0_col3, #T_2e1a4_row0_col4 {
#   color: red;
#   border: 1px black solid !important;
#   text-align: center;
# }
# </style>
# <table id="T_2e1a4">
#   <caption>Speedup UCR-DTW relative to the naive algorithm <br> (variable query length and warping path size, fixed time series length)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e1a4_level0_col0" class="col_heading level0 col0" >m = 16</th>
#       <th id="T_2e1a4_level0_col1" class="col_heading level0 col1" >m = 32</th>
#       <th id="T_2e1a4_level0_col2" class="col_heading level0 col2" >m = 64</th>
#       <th id="T_2e1a4_level0_col3" class="col_heading level0 col3" >m = 128</th>
#       <th id="T_2e1a4_level0_col4" class="col_heading level0 col4" >m = 256</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e1a4_level0_row0" class="row_heading level0 row0" >r = 0.0</th>
#       <td id="T_2e1a4_row0_col0" class="data row0 col0" >3.563383</td>
#       <td id="T_2e1a4_row0_col1" class="data row0 col1" >0.486391</td>
#       <td id="T_2e1a4_row0_col2" class="data row0 col2" >0.295234</td>
#       <td id="T_2e1a4_row0_col3" class="data row0 col3" >0.237856</td>
#       <td id="T_2e1a4_row0_col4" class="data row0 col4" >0.206887</td>
#     </tr>
#     <tr>
#       <th id="T_2e1a4_level0_row1" class="row_heading level0 row1" >r = 0.1</th>
#       <td id="T_2e1a4_row1_col0" class="data row1 col0" >3.805458</td>
#       <td id="T_2e1a4_row1_col1" class="data row1 col1" >1.549608</td>
#       <td id="T_2e1a4_row1_col2" class="data row1 col2" >1.495762</td>
#       <td id="T_2e1a4_row1_col3" class="data row1 col3" >2.399523</td>
#       <td id="T_2e1a4_row1_col4" class="data row1 col4" >2.405472</td>
#     </tr>
#     <tr>
#       <th id="T_2e1a4_level0_row2" class="row_heading level0 row2" >r = 0.2</th>
#       <td id="T_2e1a4_row2_col0" class="data row2 col0" >5.360871</td>
#       <td id="T_2e1a4_row2_col1" class="data row2 col1" >1.658275</td>
#       <td id="T_2e1a4_row2_col2" class="data row2 col2" >1.622810</td>
#       <td id="T_2e1a4_row2_col3" class="data row2 col3" >2.328657</td>
#       <td id="T_2e1a4_row2_col4" class="data row2 col4" >1.765940</td>
#     </tr>
#     <tr>
#       <th id="T_2e1a4_level0_row3" class="row_heading level0 row3" >r = 0.3</th>
#       <td id="T_2e1a4_row3_col0" class="data row3 col0" >6.229356</td>
#       <td id="T_2e1a4_row3_col1" class="data row3 col1" >1.931246</td>
#       <td id="T_2e1a4_row3_col2" class="data row3 col2" >1.661336</td>
#       <td id="T_2e1a4_row3_col3" class="data row3 col3" >2.238318</td>
#       <td id="T_2e1a4_row3_col4" class="data row3 col4" >1.334655</td>
#     </tr>
#     <tr>
#       <th id="T_2e1a4_level0_row4" class="row_heading level0 row4" >r = 0.4</th>
#       <td id="T_2e1a4_row4_col0" class="data row4 col0" >7.541585</td>
#       <td id="T_2e1a4_row4_col1" class="data row4 col1" >1.937008</td>
#       <td id="T_2e1a4_row4_col2" class="data row4 col2" >1.538685</td>
#       <td id="T_2e1a4_row4_col3" class="data row4 col3" >2.143971</td>
#       <td id="T_2e1a4_row4_col4" class="data row4 col4" >1.161010</td>
#     </tr>
#     <tr>
#       <th id="T_2e1a4_level0_row5" class="row_heading level0 row5" >r = 0.5</th>
#       <td id="T_2e1a4_row5_col0" class="data row5 col0" >8.068456</td>
#       <td id="T_2e1a4_row5_col1" class="data row5 col1" >1.900167</td>
#       <td id="T_2e1a4_row5_col2" class="data row5 col2" >1.336094</td>
#       <td id="T_2e1a4_row5_col3" class="data row5 col3" >1.745266</td>
#       <td id="T_2e1a4_row5_col4" class="data row5 col4" >1.076572</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ![equation.png](data:image/png;base64,...)
# Проанализируйте и изложите содержательный смысл полученных
# результатов.

# %% [markdown]
# *# WRITE YOUR ANSWER*

# %% [markdown]
# ### **Задача 9.**
#
# В данном задании вам предстоит определелить, какую функцию расстояния ED или DTW лучше всего использовать на практике для поиска наиболее похожих подпоследовательностей временного ряда на запрос. Чтобы это сделать, рассмотрим две задачи из различных предметных областей, решить которые предлагается с помощью алгоритмов поиска по образцу.
#
# Начнем с **первой задачи из области физиологии человека**. На человеке сначала закрепляют множество акселерометров и гироскопов, после чего он выполняет в помещении последовательность заранее определенных действий (активностей) в течение некоторого промежутка времени. Примерами таких активностей являются открывание/закрывание дверей, включение/выключение света, питье из чашки стоя/сидя и др. В то время как человек выполняет эти активности, датчики фиксируют его скорость и направление наклона тела. Задача дата-сайентиста заключается в том, что необходимо распознать в снятых данных все активности, которые выполнял человек.
#
# Данную задачу упростим, и будем выполнять поиск только одной активности во временном ряде при условии, что у нас имеется образец этой активности. В качестве данных возьмем временной ряд показаний гироскопа, закрепленного на правом запятье руки человека, из набора данных [Opportunity](https://archive.ics.uci.edu/dataset/226/opportunity+activity+recognition) и образец искомой активности, питья из чашки стоя. Данный ряд соответствует примерно 14-минутной записи.
#
# Загрузите временной ряд и образец поиска из директории `./datasets/part3/Opportunity` в ноутбук.

# %%
import os

print(os.listdir('./datasets/part3/Opportunity'))
# Out:
# ['labels.csv', 'query.csv', 'ts.csv']

# %%
opportunity_path = './datasets/part3/Opportunity'

ts = read_ts(
    f'{opportunity_path}/ts.csv'
).reshape(-1)

query = read_ts(
    f'{opportunity_path}/query.csv'
).reshape(-1)

labels = pd.read_csv(f'{opportunity_path}/labels.csv', header=None).values.reshape(-1)

# %% [markdown]
# Выполните поиск похожих подпоследовательностей на запрос с помощью реализованных вами ранее алгоритмов MASS и UCR-DTW. Согласно истинной разметке, искомую активность человек выполнял 7 раз, поэтому параметр $topK=7$.

# %%
topK = 7
r = 0.1
excl_zone_frac = 1
is_normalize = True

# MASS
mass_dist_profile = np.real(
    mts.mass(ts, query)
)

excl_zone = math.ceil(
    len(query) * excl_zone_frac
)

mass_results = topK_match(
    mass_dist_profile,
    excl_zone,
    topK
)

# UCR-DTW
ucr_dtw = UCR_DTW(
    excl_zone_frac=excl_zone_frac,
    topK=topK,
    is_normalize=is_normalize,
    r=r
)

ucr_results = ucr_dtw.perform(
    ts,
    query
)

print("MASS:")
print(mass_results)

print("\nUCR-DTW:")
print(ucr_results)
# Out:
# MASS:
# {'indices': [16662, 6663, 4244, 11787, 1906, 14269, 16101], 'distances': [11.381053961489167, 13.033659758724884, 13.543766497042725, 15.3767219473254, 15.402004025835868, 15.985912402043986, 16.091194662258587]}
#
# UCR-DTW:
# {'indices': [11799, 1916, 16663, 9291, 6650, 14264, 4248], 'distances': [8.401939356149823, 10.464902253869468, 11.081110425446342, 13.288976873807572, 13.384446257717942, 20.228229638064576, 22.794125863225588]}

# %% [markdown]
# Чтобы оценить качество распознавания активности, загрузите имеющуюся истинную разметку, хранящуюся в файле *labels.csv*. В разметке значением 1 обозначаются моменты времени, когда человек пил из чашки стоя, и значением 0 – в противном случае. Вычислите среди найденных $topK$ подпоследовательностей количество TP (True Positive) и FN (False Negative) с помощью функции `calculate_task1_accuracy()` и сравните между собой показатели, полученные с помощью MASS и UCR-DTW.

# %%
def calculate_task1_accuracy(labels: np.array, predicted_results: np.array) -> dict:
    """
    Calculate the accuracy of the algorithm which performs the activity recognition

    Parameters
    ----------
    labels: true labels
    predicted_results: results are predicted by algorithm

    Returns
    -------
        The number of True Positive and False Negative examples
    """

    TP = 0
    FN = 0

    topK = len(predicted_results['indices'])

    for i in range(topK):
        idx = predicted_results['indices'][i]
        if (labels[idx] == 1):
            TP = TP + 1

    FN = topK - TP

    return {'TP': TP,
            'FN': FN}

# %%
mass_accuracy = calculate_task1_accuracy(
    labels,
    mass_results
)

ucr_accuracy = calculate_task1_accuracy(
    labels,
    ucr_results
)

print("MASS:")
print(mass_accuracy)

print("\nUCR-DTW:")
print(ucr_accuracy)
# Out:
# MASS:
# {'TP': 6, 'FN': 1}
#
# UCR-DTW:
# {'TP': 7, 'FN': 0}

# %% [markdown]
# Итоговый вывод о преимуществе одной функции расстояния над другой в задаче поиска по образцу на данный момент делать еще рано, поэтому решим **вторую задачу из области транспорта**. Данная задача заключается в прогнозировании потока пешеходов в некоторой точке города на основе прошлых данных.
#
# Прогнозирование ряда $T$ длины $n$ будем выполнять следующим образом. Сначала сформируем запрос $Q$, состоящий из $m$ последних по времени элементов ряда, $Q = T_{n-m+1,m}$. Далее среди всех подпоследовательностей ряда $T$, начинающихся с 1 до $n-2m$ позиций, найдем $topK$ похожих на запрос $Q$. Обозначим за $h > 0$ горизонт прогнозирования, определяющий количество элементов ряда, значения которых необходимо спрогнозировать. Для нахождения будущих значений будем брать $h$ элементов ряда, которые следуют за концевыми точками найденных похожих подпоследовательностей. В итоге, будущие значения будут получаться путем применения агрегатной функции к этим элементам. В качестве агрегатной функции может использоваться среднее арифметическое, взвешенное среднее, медиана и др.
#
# Загрузите временной ряд из файла *pedestrian_count.csv*, расположенного в директории *./datasets/part3/Melbourne*. Данный ряд содержит почасовую статистику о количестве пешеходов на улице Бурке в Мельбурне (Австралия), являющейся одной из главных улиц города. Данные собраны за период с 1 марта 2020 по 31 октября 2022 гг. Полный набор данных и его детальное описание доступны по следующей [ссылке](https://data.melbourne.vic.gov.au/explore/dataset/pedestrian-counting-system-monthly-counts-per-hour/information/).

# %%
data_path = './datasets/part3/Melbourne/pedestrian_count.csv'

data = pd.read_csv(data_path, header=0)

# %%
data.head()
data['dt'] = pd.to_datetime(data['Date_Time'])
data = data.sort_values(by='dt')
ts = data['Hourly_Counts'].values
ts
# Out:
# C:\Users\wala-\AppData\Local\Temp\ipykernel_16244\3074410354.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['dt'] = pd.to_datetime(data['Date_Time'])
# array([579, 515, 281, ...,   4,   0,  22], dtype=int64)

# %% [markdown]
# Реализуйте алгоритм прогнозирования временного ряда на основе UCR-DTW и MASS, следуя приведенному выше описанию. За прогнозирование отвечает класс `BestMatchPredictor` из модуля *prediction.py*, дополните его недостающим кодом.
#
# Далее выполните прогнозирование потока людей для исходных данных на 1 день вперед (24 значения). Для этого установите следующие входные параметры:
# <ul>
#   <li>$h = 24$ (горизонт прогнозирования);</li>
#   <li>$m = 168$ (длина запроса и подпоследовательностей, соответствующая 1 неделе);</li>
#   <li>$aggr\_func = \text{'average'}$ (агрегатная функция);</li>
#   <li>для алгоритма UCR-DTW:
#     <ul>
#       <li>$topK = 5$ (количество похожих подпоследовательностей на запрос);</li>
#       <li>$r = 0.1$ (ширина полосы Сако–Чиба);</li>
#       <li>$excl\_zone\_frac = 1$ (доля от длины подпоследовательностей, на основе которой определяется, являются ли подпоследоватлеьности тривиальными совпадениями);</li>
#       <li>$is\_normalize = True$ ($z$-нормализация запроса и подпоследовательностей);</li>
#     </ul>
#   </li>
#   <li>для алгоритма MASS:</li>
#     <ul>
#       <li>$topK = 5$ (количество похожих подпоследовательностей на запрос);</li>
#       <li>$excl\_zone\_frac = 1$ (доля от длины подпоследовательностей, на основе которой определяется, являются ли подпоследоватлеьности тривиальными совпадениями).</li>
#     </ul>
# </ul>
#
# Будем считать, что последние $h$ значений в загруженном временном ряде $T$ длины $n$ отсутствуют. Поэтому перед тем как находить прогнозные значения,  подготовьте данные. Разделите загруженный временной ряд $T$ на три части:
# <ol>
#   <li>ряд $T_{train}$, в котором будет выполняться поиск похожих подпоследовательностей на запрос $Q$: $T_{train} = T[0:(n-m-h)]$</li>
#   <li>запрос $Q$: $Q = T[(n-m-h) : (n-h)]$</li>
#   <li>реальные значения ряда $real\_values$, которые необходимо спрогнозировать: $real\_values = T[-h:] $</li>
# </ol>

# %%
ucr_dtw_params = {
    'topK': 5,
    'r': 0.1,
    'excl_zone_frac': 1,
    'is_normalize': True
}

mass_params = {
    'topK': 5,
    'excl_zone_frac': 1
}

h = 24
m = 168

ts = data.iloc[:, 0].to_numpy()

n = len(ts)
train = ts[0:n-m-h]  # ряд для поиска
query_ped = ts[n-m-h:n-h]  # запрос
real_values = ts[-h:]  # реальные значения для проверки

# %%
ucr_predictor = BestMatchPredictor(
    h=24,
    match_alg='UCR-DTW',
    match_alg_params=ucr_dtw_params,
    aggr_func='average'
)

ucr_prediction = ucr_predictor.predict(
    train,
    query
)

print("UCR-DTW prediction:")
print(ucr_prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 8
#       1 ucr_predictor = BestMatchPredictor(
#       2     h=24,
#       3     match_alg='UCR-DTW',
#       4     match_alg_params=ucr_dtw_params,
#       5     aggr_func='average'
#       6 )
# ----> 8 ucr_prediction = ucr_predictor.predict(
#       9     train,
#      10     query
#      11 )
#      13 print("UCR-DTW prediction:")
#      14 print(ucr_prediction)
#
# File ~\Desktop\tscourse\2026-Snedkov-TimeSeriesCourse\practice\02 Similarity search\modules\prediction.py:102, in BestMatchPredictor.predict(self, ts, query)
#      93 if self.match_alg == 'UCR-DTW':
#      95     finder = UCR_DTW(
#      96         excl_zone_frac=self.match_alg_params['excl_zone_frac'],
#      97         topK=self.match_alg_params['topK'],
#      98         is_normalize=self.match_alg_params['is_normalize'],
#      99         r=self.match_alg_params['r']
#     100     )
# --> 102     bestmatch = finder.perform(
#     103         search_ts,
#     104         query
#     105     )
#     107     indices = bestmatch['indices']
#     109 elif self.match_alg == 'MASS':
#
# File ~\Desktop\tscourse\2026-Snedkov-TimeSeriesCourse\practice\02 Similarity search\modules\bestmatch.py:295, in UCR_DTW.perform(self, ts_data, query)
#     293 query = copy.deepcopy(query)
#     294 if (len(ts_data.shape) != 2): # time series set
# --> 295     ts_data = sliding_window(ts_data, len(query))
#     297 N, m = ts_data.shape
#     299 excl_zone = self._calculate_excl_zone(m)
#
# File ~\Desktop\tscourse\2026-Snedkov-TimeSeriesCourse\practice\02 Similarity search\modules\utils.py:67, in sliding_window(ts, window, step)
#      65     start_idx = i*step
#      66     end_idx = start_idx + window
# ---> 67     subs_matrix[i] = ts[start_idx:end_idx]
#      69 return subs_matrix
#
# ValueError: could not convert string to float: 'March 01, 2020 12:00:00 AM'

# %%
mass_predictor = BestMatchPredictor(
    h=24,
    match_alg='MASS',
    match_alg_params=mass_params,
    aggr_func='average'
)

mass_prediction = mass_predictor.predict(
    train,
    query
)

print("MASS prediction:")
print(mass_prediction)

# %% [markdown]
# Далее выполните сравнение эффективности алгоритма при UCR-DTW и MASS по точности прогнозирования. Для оценки точности используйте **меру
# среднеквадратичной ошибки RMSE (Root Mean Square Error)**, которая определяется следующим образом:
# \begin{equation}
# RMSE = \sqrt{\frac{1}{h}\sum_{i=1}^h{(t_i-\tilde{t}_i)}^2},
# \end{equation}
# где $t_i$ и $\tilde{t}_i$ — фактическое и прогнозное значения элемента ряда, $h$ — количество прогнозных элементов временного ряда.

# %%
from sklearn.metrics import mean_squared_error

ucr_rmse = np.sqrt(
    mean_squared_error(real_values, ucr_prediction)
)

mass_rmse = np.sqrt(
    mean_squared_error(real_values, mass_prediction)
)

print(f"UCR-DTW RMSE: {ucr_rmse:.2f}")
print(f"MASS RMSE: {mass_rmse:.2f}")

# %% [markdown]
# ![equation.png](data:image/png;base64,...) Сделайте вывод о влиянии функции расстояния ED и DTW на точность решения задач интеллектульного анализа данных, которые основаны на алгоритмах поиска по образцу.

# %% [markdown]
# *# WRITE YOUR ANSWER*
